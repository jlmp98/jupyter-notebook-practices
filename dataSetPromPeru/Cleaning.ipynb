# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
def init_clean(filename="Vacacionista.csv"):
    d=pd.read_csv(filename, encoding='latin-1')
    print("init",d.shape)
    d.drop(d.columns[[0,1,2]],axis=1,inplace=True)
    d.dropna(axis=1, how='all',inplace=True)
    print("end",d.shape)
    return d
data = init_clean()
# Out:
# init (1548, 2509)
# end (1548, 1238)

# %%
data.head()
# Out:
#    LUGAR  P02_1  P02_2  P02_3  P02_4  P02_5  P02_6  P02_7  P02_8  P02_9  \
# 0      1    1.0    5.0    6.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1      1    1.0    5.0    6.0   32.0   75.0    NaN    NaN    NaN    NaN
# 2      1    1.0    5.0    6.0   75.0    NaN    NaN    NaN    NaN    NaN
# 3      1    1.0    5.0    6.0   28.0   75.0    NaN    NaN    NaN    NaN
# 4      1    1.0    5.0    6.0    7.0    NaN    NaN    NaN    NaN    NaN
#
#       ...       P64A  P65_1  P65_2  P65_HijosDep  P66  P68  P69  \
# 0     ...          2      5    NaN             2    9    4   99
# 1     ...          2      2    NaN             1    3    4    5
# 2     ...          2      2    NaN             1    3    6    7
# 3     ...          1      5    NaN             2    4    2   99
# 4     ...          1      1    NaN             2    2    6    8
#
#    GastoPorPersona  GPC_SA_Ran         PESO
# 0      1201.787274           3  1103.488318
# 1      1250.000000           3   255.312849
# ...

# %%
df = data[data.columns[1:21]]

# %%
df.P02_1.str.get_dummies()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-ad2147de5a5c> in <module>()
# ----> 1 df.P02_1.str.get_dummies()
#
# /home/yuselenin_anquise/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    2964         if (name in self._internal_names_set or name in self._metadata or
#    2965                 name in self._accessors):
# -> 2966             return object.__getattribute__(self, name)
#    2967         else:
#    2968             if name in self._info_axis:
#
# /home/yuselenin_anquise/anaconda3/lib/python3.6/site-packages/pandas/core/base.py in __get__(self, instance, owner)
#     241             # this ensures that Series.str.<method> is well defined
#     242             return self.accessor_cls
# --> 243         return self.construct_accessor(instance)
#     244
#     245     def __set__(self, instance, value):
#
# ...
